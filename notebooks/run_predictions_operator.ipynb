# %%
import itertools
import operator
import sys
import os
sys.path.append("../src")
from glob import glob

# %%
search_root = "/checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/"
checkpoint_name = "best_em.ckpt"
files = glob("{}/**/{}".format(search_root,checkpoint_name), recursive=True)


print(len(files))
# Out:
# 150

# %%
def expand(idx,chunk):

  #elif idx == 1:
  #  return ["experiment={}".format(chunk)]
  if chunk.startswith("seed-"):
    return ["seed={}".format(chunk.replace("seed-",""))]
  elif "," in chunk:
    return chunk.split(",")
  elif "=" in chunk:
    return [chunk]
  return []


experiments = []
for file in files:
    chunks = file.replace(search_root,"").split("/")
    chunks = itertools.chain(*[expand(idx, chunk) for idx, chunk in enumerate(chunks)])

    data = {k:v for k,v in (chunk.split("=") for chunk in chunks)}
    data["file"] = file
    data['dir'] = os.path.dirname(file)
    #if data["version"] in ["v1.1.2", "v1.1.3", "v1.1.4"]:
    experiments.append(data)


print (len(experiments))
# Out:
# 150

# %%
for exp in experiments:
    version = "v1.2_resolv_100k"
    print("python -m neuraldb.commands.t5train2_operator "
          "--output_dir {} "
          "--model_name_or_path t5-base "
          "--do_predict "
          "--eval_batch_size 128 "
          "--n_gpu 4 "
          "--test_name metrics_test.jsonl "
          "--train_path={}/generated_clean_train.jsonl "
          "--val_path={}/generated_clean_val.jsonl "
          "--test_path={}/generated_clean_test.jsonl "
          .format(exp['dir'],version,version,version))
# Out:
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=1/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-6,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# ...
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-5,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=1e-05/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=5e-05/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0001/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.0005/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-2 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-1 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-5 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-4 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
# python -m neuraldb.commands.t5train2_operator --output_dir /checkpoint/jth/job_staging/neuraldb_expts/experiment=operator_finetune/dataset=operator,model=t5-base,version=v1.2_resolv_100k/ft_lr=8e-4,ft_epochs=2/filters=P6.P19.P20.P21.P22.P23.P38.P54.P1831.P1867,train_percentage=0.001/seed-3 --model_name_or_path t5-base --do_predict --eval_batch_size 128 --n_gpu 4 --test_name metrics_test.jsonl --train_path=v1.2_resolv_100k/generated_clean_train.jsonl --val_path=v1.2_resolv_100k/generated_clean_val.jsonl --test_path=v1.2_resolv_100k/generated_clean_test.jsonl
